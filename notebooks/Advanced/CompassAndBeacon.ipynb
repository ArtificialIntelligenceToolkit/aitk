# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/ArtificialIntelligenceToolkit/aitk/blob/master/notebooks/Advanced/CompassAndBeacon.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install aitk --quiet

# %%
from aitk.robots import World, load_world, Scribbler, Beacon, Compass

# %%
w = World(200, 200)
# Out:
# Random seed set to: 1124080

# %%
w.watch()
# Out:
# Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x0…

# %%
w.add_beacon(100, 100, 0)

# %%
robot = Scribbler()

# %%
w.add_robot(robot)

# %%
robot.add_device(Compass())

# %%
robot[0].watch()

# %%
import random

robot.move(1,0)
def wander(robot):
    if robot.stalled:
        robot.reverse()
    else:
        robot.rotate(random.random())
# Out:
# This world is not running

# %%
w.run([wander])
# Out:
# 0it [00:00, ?it/s]
# Simulation stopped at: 00:01:26.7; speed 0.99 x real time
