# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/ArtificialIntelligenceToolkit/aitk/blob/master/notebooks/Advanced/SimpleController.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install aitk --quiet

# %%
import aitk.robots as bots
bots.__version__
# Out:
# '0.8.3'

# %%
world = bots.World(width=100, height=100, scale=5.0)
robot = bots.Scribbler(x=80, y=50, a=135)
world.add_robot(robot)
# Out:
# Random seed set to: 7102300

# %%
world.watch()
# Out:
# Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x0…

# %%
from random import random

def simple(robot):
    if robot.world.time%2 == 0.0:
        robot.move(random(), random()*0.5-0.25)
    if robot.stalled:
        robot.reverse()

# %%
world.reset()
world.seconds(120,[simple])
# Out:
# Using random seed: 7102300
# Simulation stopped at: 00:00:58.6; speed 0.98 x real time
