# %%
import numpy as np

# %%
def get_digit_inputs():
    """Each digit is represented by a 6x6 grid of 1's and 0's separated by blank lines."""
    fp = open("digits.data", "r")
    data = []
    while True:
        digit = []
        line = fp.readline()
        while len(line) != 0 and (line[0] == '0' or line[0] == '1'):
            line.strip()
            values = line.split()
            digit += [int(v) for v in values]
            line = fp.readline()
        if len(line) == 0:
            break
        if len(digit) > 0:
            data.append(digit)
    return np.array(data)

# %%
inputs = get_digit_inputs()
inputs.shape
# Out:
# (240, 36)

# %%
def one_hot(length, index):
    vec = [0]*length
    vec[index] = 1
    return vec

# %%
def get_digit_targets(n):
    """Create n repetitions of 10 one-hot vectors"""
    data = []
    for i in range(n):
        for j in range(10):
            data.append(one_hot(10, j))
    return np.array(data)

# %%
targets = get_digit_targets(24)
targets.shape
# Out:
# (240, 10)

# %%
from aitk.networks import SimpleNetwork

# %%
def build_model():
    net = SimpleNetwork(36, (8, "sigmoid"), (10, "softmax"),
        loss = "categorical_crossentropy",
        metrics = ["tolerance_accuracy"]
        )
    net.set_config_layer("input", vshape=(6,6,1), colormap=("gray",0,1))
    net.set_learning_rate(0.1)
    net.set_momentum(0.0)
    return net

# %%
net = build_model()
net.set_tolerance(0.2)

# %%
history = net.fit(
    inputs, targets, 
    batch_size=16, 
    shuffle=True,
    epochs=600, 
    accuracy=1.0, 
    patience=30, 
    report_rate=10,
)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (https://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 720 288" width="720pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <metadata>
#   <rdf:RDF xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2021-03-06T12:31:16.613693</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.3.4, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 288
# L 720 288
# L 720 0
# L 0 0
# z
# " style="fill:none;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 90 252
# L 343.636364 252
# L 343.636364 34.56
# L 90 34.56
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <defs>
#        <path d="M 0 0
# L 0 3.5
# " id="mf0db759eeb" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="101.143987" xlink:href="#mf0db759eeb" y="252"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- 0 -->
#       <g transform="translate(97.962737 266.598437)scale(0.1 -0.1)">
#        <defs>
#         <path d="M 31.78125 66.40625
# Q 24.171875 66.40625 20.328125 58.90625
# Q 16.5 51.421875 16.5 36.375
# Q 16.5 21.390625 20.328125 13.890625
# Q 24.171875 6.390625 31.78125 6.390625
# Q 39.453125 6.390625 43.28125 13.890625
# Q 47.125 21.390625 47.125 36.375
# Q 47.125 51.421875 43.28125 58.90625
# Q 39.453125 66.40625 31.78125 66.40625
# z
# M 31.78125 74.21875
# Q 44.046875 74.21875 50.515625 64.515625
# Q 56.984375 54.828125 56.984375 36.375
# Q 56.984375 17.96875 50.515625 8.265625
# Q 44.046875 -1.421875 31.78125 -1.421875
# Q 19.53125 -1.421875 13.0625 8.265625
# Q 6.59375 17.96875 6.59375 36.375
# Q 6.59375 54.828125 13.0625 64.515625
# Q 19.53125 74.21875 31.78125 74.21875
# z
# " id="DejaVuSans-48"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-48"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_2">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="139.637895" xlink:href="#mf0db759eeb" y="252"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 100 -->
#       <g transform="translate(130.094145 266.598437)scale(0.1 -0.1)">
#        <defs>
#         <path d="M 12.40625 8.296875
# L 28.515625 8.296875
# L 28.515625 63.921875
# L 10.984375 60.40625
# L 10.984375 69.390625
# L 28.421875 72.90625
# L 38.28125 72.90625
# L 38.28125 8.296875
# L 54.390625 8.296875
# L 54.390625 0
# L 12.40625 0
# z
# " id="DejaVuSans-49"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-49"/>
#        <use x="63.623047" xlink:href="#DejaVuSans-48"/>
#        <use x="127.246094" xlink:href="#DejaVuSans-48"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_3">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="178.131804" xlink:href="#mf0db759eeb" y="252"/>
#       </g>
#      </g>
#      <g id="text_3">
#       <!--
/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_6">
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="293.613529" xlink:href="#mf0db759eeb" y="252"/>
#       </g>
#      </g>
#      <g id="text_6">
#       <!-- 500 -->
#       <g transform="translate(284.069779 266.598437)scale(0.1 -0.1)">
#        <defs>
#         <path d="M 10.796875 72.90625
# L 49.515625 72.90625
# L 49.515625 64.59375
# L 19.828125 64.59375
# L 19.828125 46.734375
# Q 21.96875 47.46875 24.109375 47.828125
# Q 26.265625 48.1875 28.421875 48.1875
# Q 40.625 48.1875 47.75 41.5
# Q 54.890625 34.8125 54.890625 23.390625
# Q 54.890625 11.625 47.5625 5.09375
# Q 40.234375 -1.421875 26.90625 -1.421875
# Q 22.3125 -1.421875 17.546875 -0.640625
# Q 12.796875 0.140625 7.71875 1.703125
# L 7.71875 11.625
# Q 12.109375 9.234375 16.796875 8.0625
# Q 21.484375 6.890625 26.703125 6.890625
# Q 35.15625 6.890625 40.078125 11.328125
# Q 45.015625 15.765625 45.015625 23.390625
# Q 45.015625 31 40.078125 35.4375
# Q 35.15625 39.890625 26.703125 39.890625
# Q 22.75 39.890625
# Epoch 600/600 loss: 0.05745095759630203 - tolerance_accuracy: 0.9583333134651184

# %%
for pattern in inputs[0:20]:
    net.display(pattern)
    x = input("press enter")
# Out:
# <svg id='keras-network' xmlns='http://www.w3.org/2000/svg' xmlns:xlink='http://www.w3.org/1999/xlink' image-rendering="pixelated" width="341px" height="400px" style="background-color: #B0C4DE">
#  <g >
#   <svg viewBox="0 0 350 410" width="341px" height="400px">
#     <defs>
#         <marker id="arrow" markerWidth="10" markerHeight="10" refX="9" refY="3" orient="auto" markerUnits="strokeWidth">
#           <path d="M0,0 L0,6 L9,3 z" fill="black" />
#         </marker>
#     </defs><rect x="74.0" y="24" width="202" height="52" style="fill:none;stroke:black;stroke-width:2"/><image id="keras-network_output" class="keras-network" x="75.0" y="25" height="50" width="200" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: output 'Dense'
# Act function: softmax
# Act output range: (0, 1)
# Shape = (None, 10)</title><text x="280.0" y="52.0" font-family="monospace" font-size="12" text-anchor="start" fill="blue" alignment-baseline="central" >output</text><path d="M 175.0 104 L 175.0 77 " stroke="black" stroke-width="2" marker-end="url(#arrow)" fill="none" /><rect x="74.0" y="104" width="202" height="52" style="fill:none;stroke:black;stroke-width:2"/><image id="keras-network_hidden" class="keras-network" x="75.0" y="105" height="50" width="200" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: hidden 'Dense'
# Act function: sigmoid
# Act output range: (0, 1)
# Shape = (None, 8)</title><text x="280.0" y="132.0" font-family="monospace" font-size="12" text-anchor="start" fill="blue" alignment-baseline="central" >hidden</text><path d="M 175.0 184 L 175.0 157 " stroke="black" stroke-width="2" marker-end="url(#arrow)" fill="none" /><rect x="74.0" y="184" width="202" height="202" style="fill:none;stroke:black;stroke-width:2"/><image id="keras-network_input" class="keras-network" x="75.0" y="185" height="200" width="200" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: input 'InputLayer'
# Shape = [(None, 36)]</title><text x="280.0" y="287.0" font-family="monospace" font-size="12" text-anchor="start" fill="blue" alignment-baseline="central" >input</text><text x="175.0" y="12.5" font-family="monospace" font-size="15" text-anchor="middle" fill="black" alignment-baseline="central" >Activations for SimpleNetwork</text></svg></g></svg>
# press enter

# %%
# Give each digit it's own color
colors = ["pink", "red", "orange", "yellow", "green", 
          "teal", "blue", "indigo", "violet", "black"]

# %%
net.predict_pca(inputs, colors=colors*24)
# Out:
# <svg id='keras-network' xmlns='http://www.w3.org/2000/svg' xmlns:xlink='http://www.w3.org/1999/xlink' image-rendering="pixelated" width="275px" height="400px" style="background-color: #B0C4DE">
#  <g >
#   <svg viewBox="0 0 350 509" width="275px" height="400px">
#     <defs>
#         <marker id="arrow" markerWidth="10" markerHeight="10" refX="9" refY="3" orient="auto" markerUnits="strokeWidth">
#           <path d="M0,0 L0,6 L9,3 z" fill="black" />
#         </marker>
#     </defs><rect x="74.0" y="24" width="202" height="135" style="fill:none;stroke:black;stroke-width:2"/><image id="keras-network_output" class="keras-network" x="75.0" y="25" height="133" width="200" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: output 'Dense'
# Act function: softmax
# Act output range: (0, 1)
# Shape = (None, 10)</title><text x="280.0" y="93.5" font-family="monospace" font-size="12" text-anchor="start" fill="blue" alignment-baseline="central" >output</text><path d="M 175.0 187 L 175.0 160 " stroke="black" stroke-width="2" marker-end="url(#arrow)" fill="none" /><rect x="74.0" y="187" width="202" height="135" style="fill:none;stroke:black;stroke-width:2"/><image id="keras-network_hidden" class="keras-network" x="75.0" y="188" height="133" width="200" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: hidden 'Dense'
# Act function: sigmoid
# Act output range: (0, 1)
# Shape = (None, 8)</title><text x="280.0" y="256.5" font-family="monospace" font-size="12" text-anchor="start" fill="blue" alignment-baseline="central" >hidden</text><path d="M 175.0 350 L 175.0 323 " stroke="black" stroke-width="2" marker-end="url(#arrow)" fill="none" /><rect x="74.0" y="350" width="202" height="135" style="fill:none;stroke:black;stroke-width:2"/><image id="keras-network_input" class="keras-network" x="75.0" y="351" height="133" width="200" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: input 'InputLayer'
# Shape = [(None, 36)]</title><text x="280.0" y="419.5" font-family="monospace" font-size="12" text-anchor="start" fill="blue" alignment-baseline="central" >input</text><text x="175.0" y="12.5" font-family="monospace" font-size="15" text-anchor="middle" fill="black" alignment-baseline="central" >PCAs for SimpleNetwork</text></svg></g></svg>

# %%
from scipy.cluster import hierarchy

# %%
labelList = [str(v) for v in range(10)]

# %%
hidden_raw = net.predict_to(inputs, "hidden")

# %%
result = hierarchy.dendrogram(
    hierarchy.linkage(hidden_raw[30:60],method='ward'),
    orientation="left", 
    labels=labelList*3,
)
